# %%
import torch
import torch.nn as nn

# %%
class DeeperCNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 4 * 4, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
model = DeeperCNN(num_classes=10)

dummy = torch.randn(2, 3, 32, 32)

# %%
output = model(dummy)
print(f"输入: {dummy.shape} -> 输出: {output.shape}")
# Out:
# 输入: torch.Size([2, 3, 32, 32]) -> 输出: torch.Size([2, 10])

# %%
x = dummy
for i, layer in enumerate(model.features):
    x = layer(x)
    print(f"features[{i}] {layer.__class__.__name__:15s} -> {x.shape}")
# Out:
# features[0] Conv2d          -> torch.Size([2, 32, 32, 32])
# features[1] BatchNorm2d     -> torch.Size([2, 32, 32, 32])
# features[2] ReLU            -> torch.Size([2, 32, 32, 32])
# features[3] MaxPool2d       -> torch.Size([2, 32, 16, 16])
# features[4] Conv2d          -> torch.Size([2, 64, 16, 16])
# features[5] BatchNorm2d     -> torch.Size([2, 64, 16, 16])
# features[6] ReLU            -> torch.Size([2, 64, 16, 16])
# features[7] MaxPool2d       -> torch.Size([2, 64, 8, 8])
# features[8] Conv2d          -> torch.Size([2, 128, 8, 8])
# features[9] BatchNorm2d     -> torch.Size([2, 128, 8, 8])
# features[10] ReLU            -> torch.Size([2, 128, 8, 8])
# features[11] MaxPool2d       -> torch.Size([2, 128, 4, 4])

# %%
total = sum(p.numel() for p in model.parameters())
print(f"总参数量: {total:,}")
# Out:
# 总参数量: 620,810
