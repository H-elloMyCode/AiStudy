# %%
import torch
import torch.nn as nn

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim=100, img_dim=784):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.ReLU(True),
            nn.Linear(256, 512),
            nn.ReLU(True),
            nn.Linear(512, 1024),
            nn.ReLU(True),
            nn.Linear(1024, img_dim),
            nn.Tanh()
        )

    def forward(self, z):
        return self.net(z)

# %%
if __name__ == '__main__':
    G = Generator(latent_dim=100, img_dim=784)
    z = torch.randn(16, 100)
    fake_img = G(z)
    print(f"噪声形状: {z.shape}")
    print(f"生成图片形状: {fake_img.shape}")
# Out:
# 噪声形状: torch.Size([16, 100])
# 生成图片形状: torch.Size([16, 784])
