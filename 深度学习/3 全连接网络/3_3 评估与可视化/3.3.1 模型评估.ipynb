# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(784, 256),
            nn.ReLU(),
            nn.Linear(256, 10),
        )

    def forward(self, x):
        return self.net(x)

# %%
model = MLP()

# %%
X_test = torch.randn(200, 784)
X_test
# Out:
# tensor([[ 1.7546,  1.6599, -0.8410,  ..., -0.6386, -0.2057,  1.0764],
#         [ 0.2274,  0.3430, -0.2402,  ...,  0.8879,  1.3511,  1.9956],
#         [ 1.1780,  2.0375,  0.4264,  ...,  0.0544,  0.6583, -0.3727],
#         ...,
#         [-1.5269,  0.6543,  0.9783,  ..., -1.2919, -0.9931, -0.8046],
#         [-0.4857,  0.1605, -1.5478,  ..., -1.3624,  0.9460, -1.1060],
#         [ 0.9305,  0.0511, -0.2451,  ..., -1.1252,  1.2225, -0.5587]])

# %%
y_test = torch.randint(0, 10, (200, ))

# %%
y_test
# Out:
# tensor([4, 4, 2, 7, 7, 1, 8, 3, 6, 8, 3, 8, 6, 6, 9, 0, 0, 6, 2, 2, 2, 9, 0, 0,
#         5, 4, 1, 3, 7, 6, 1, 6, 7, 2, 7, 9, 2, 4, 9, 5, 5, 9, 7, 7, 5, 3, 1, 5,
#         0, 0, 3, 6, 9, 8, 1, 4, 5, 7, 1, 6, 3, 6, 7, 0, 9, 5, 0, 3, 0, 6, 9, 4,
#         1, 9, 9, 2, 4, 7, 8, 2, 0, 5, 4, 2, 9, 3, 8, 7, 7, 3, 0, 0, 9, 9, 9, 8,
#         8, 1, 3, 2, 0, 1, 7, 3, 4, 6, 7, 5, 9, 3, 1, 0, 0, 3, 2, 8, 7, 9, 8, 1,
#         4, 0, 3, 0, 6, 8, 2, 4, 5, 4, 8, 7, 9, 8, 3, 2, 1, 6, 5, 2, 9, 7, 0, 8,
#         2, 0, 3, 1, 9, 1, 3, 9, 0, 7, 5, 3, 1, 4, 1, 1, 5, 7, 6, 0, 3, 2, 5, 9,
#         6, 6, 6, 9, 7, 5, 7, 1, 8, 1, 4, 3, 8, 8, 7, 2, 0, 0, 8, 9, 4, 5, 2, 0,
#         6, 8, 7, 8, 5, 2, 0, 7])

# %%
test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=64)

# %%
model.eval()
# Out:
# MLP(
#   (net): Sequential(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
correct = 0
total = 0

# %%
with torch.no_grad():
    for batch_x, batch_y in test_loader:
        logits = model(batch_x)
        preds = torch.argmax(logits, dim=1)
        correct += (preds == batch_y).sum().item()
        total += batch_y.size(0)

# %%
accuracy = correct / total

# %%
print(f"测试集准确率: {accuracy:.2%}")
# Out:
# 测试集准确率: 8.50%
