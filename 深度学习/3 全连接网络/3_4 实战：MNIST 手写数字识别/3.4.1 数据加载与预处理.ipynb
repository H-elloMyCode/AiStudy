# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)),
])

# %%
train_dataset = datasets.MNIST(
    root='./data',
    train=True,
    transform=transform,
    download=True
)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %%
test_dataset = datasets.MNIST(
    root='./data',
    train=False,  # 测试集
    transform=transform,
    download=True,
)

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

# %%
print(f"训练集大小: {len(train_dataset)}")  # 60000
print(f"测试集大小: {len(test_dataset)}")   # 10000
# Out:
# 训练集大小: 60000
# 测试集大小: 10000

# %%
images, labels = next(iter(train_loader))

# %%
print(f"图片形状: {images.shape}")  # [64, 1, 28, 28]
print(f"标签形状: {labels.shape}")  # [64]
print(f"标签示例: {labels[:10].tolist()}")
# Out:
# 图片形状: torch.Size([64, 1, 28, 28])
# 标签形状: torch.Size([64])
# 标签示例: [8, 2, 0, 7, 9, 5, 6, 1, 4, 7]
