# %%
import torch
import numpy as np

# %%
np_arr = np.array([1.0, 2.0, 3.0])
print(np_arr)
# Out:
# [1. 2. 3.]

# %%
print(np_arr.dtype)
# Out:
# float64

# %%
tensor = torch.from_numpy(np_arr)

# %%
print(tensor)
# Out:
# tensor([1., 2., 3.], dtype=torch.float64)

# %%
tensor2 = torch.tensor([4.0, 5.0, 6.0])
print(tensor2)
# Out:
# tensor([4., 5., 6.])

# %%
np_arr2 = tensor2.numpy()
print(np_arr2)
# Out:
# [4. 5. 6.]

# %%
np_arr = np.array([1.0, 2.0, 3.0])
print(np_arr)
# Out:
# [1. 2. 3.]

# %%
tensor = torch.from_numpy(np_arr)
print(tensor)
# Out:
# tensor([1., 2., 3.], dtype=torch.float64)

# %%
tensor[0] = 99.0
print(tensor)
# Out:
# tensor([99.,  2.,  3.], dtype=torch.float64)

# %%
print(np_arr[0])
# Out:
# 99.0

# %%
print(np_arr)
# Out:
# [99.  2.  3.]

# %%
print(np_arr)
# Out:
# [99.  2.  3.]

# %%
np_arr[1] = 88.0
print(np_arr)
# Out:
# [99. 88.  3.]

# %%
print(tensor)
# Out:
# tensor([99., 88.,  3.], dtype=torch.float64)

# %%
np_arr = np.array([1.0, 2.0, 3.0])
print(np_arr)
# Out:
# [1. 2. 3.]

# %%
tensor = torch.from_numpy(np_arr).clone()
tensor
# Out:
# tensor([1., 2., 3.], dtype=torch.float64)

# %%
tensor[0] = 99.0
tensor
# Out:
# tensor([99.,  2.,  3.], dtype=torch.float64)

# %%
print(np_arr)
# Out:
# [1. 2. 3.]

# %%
tensor2 = torch.tensor(np_arr)

# %%
tensor2
# Out:
# tensor([1., 2., 3.], dtype=torch.float64)

# %%
tensor2[0] = 100.0

# %%
tensor2
# Out:
# tensor([100.,   2.,   3.], dtype=torch.float64)

# %%
print(np_arr)
# Out:
# [1. 2. 3.]
