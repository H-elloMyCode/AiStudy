# %%
import torch

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
import torch.nn.functional as F

# %%
x = torch.tensor([-2.0, -1.0, 0.0, 1.0, 2.0])

# %%
x
# Out:
# tensor([-2., -1.,  0.,  1.,  2.])

# %%
relu_out = F.relu(x)

print(f"ReLU:    {relu_out}")
# Out:
# ReLU:    tensor([0., 0., 0., 1., 2.])

# %%
sigmoid_out = torch.sigmoid(x)

print(f"Sigmoid: {sigmoid_out}")
# Out:
# Sigmoid: tensor([0.1192, 0.2689, 0.5000, 0.7311, 0.8808])

# %%
scores = torch.tensor([2.0, 1.0, 0.1])
scores
# Out:
# tensor([2.0000, 1.0000, 0.1000])

# %%
softmax_out = F.softmax(scores, dim=0)

print(f"Softmax: {softmax_out}")
# Out:
# Softmax: tensor([0.6590, 0.2424, 0.0986])

# %%
print(f"求和: {softmax_out.sum():.4f}")
# Out:
# 求和: 1.0000
