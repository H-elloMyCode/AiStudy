# %%
import numpy as np

# %%
arr_2d = np.array([[10, 20, 30], [40, 50, 60]])
print(arr_2d)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
print(arr_2d[0, 1])
# Out:
# 20

# %%
print(arr_2d[1, -1])
# Out:
# 60

# %%
print(arr_2d[1][0])
# Out:
# 40

# %%
print(arr_2d)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
print(arr_2d[0])
# Out:
# [10 20 30]

# %%
print(arr_2d[1])
# Out:
# [40 50 60]

# %%
print(arr_2d[-1])
# Out:
# [40 50 60]

# %%
print(arr_2d[:, 1])
# Out:
# [20 50]

# %%
print(arr_2d[:, -1])
# Out:
# [30 60]

# %%
print(arr_2d)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
arr_2d[1, 2] = 600

# %%
print(arr_2d)
# Out:
# [[ 10  20  30]
#  [ 40  50 600]]

# %%
arr_2d[0] = [1, 2, 3]

# %%
print(arr_2d)
# Out:
# [[  1   2   3]
#  [ 40  50 600]]

# %%
arr_2d[:, 0] = [100, 200]
print(arr_2d)
# Out:
# [[100   2   3]
#  [200  50 600]]
