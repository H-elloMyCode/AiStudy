# %%
import numpy as np

# %%
arr_2d = np.array([[1, 2, 3], [4, 5, 6]])
print(arr_2d)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr_3d = arr_2d.reshape(2, 1, 3)
print(arr_3d)
# Out:
# [[[1 2 3]]
#
#  [[4 5 6]]]

# %%
print(arr_3d.shape)
# Out:
# (2, 1, 3)

# %%
print(arr_2d.reshape(-1))
# Out:
# [1 2 3 4 5 6]

# %%
print(arr_3d)
# Out:
# [[[1 2 3]]
#
#  [[4 5 6]]]

# %%
arr_2d_new = arr_3d.reshape((3, 2))
print(arr_2d_new)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
arr_3d = np.array([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])
print(arr_3d)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]

# %%
arr_flat1 = arr_3d.reshape(-1)
print(arr_flat1)
# Out:
# [1 2 3 4 5 6 7 8]

# %%
arr_flat2 = arr_3d.ravel()
print(arr_flat2)
# Out:
# [1 2 3 4 5 6 7 8]
