# %%
import numpy as np

# %%
arr1 = np.array([[1, 2, 3], [4, 5, 6]])
arr2 = np.array([[7, 8, 9], [10, 11, 12]])

# %%
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr2)
# Out:
# [[ 7  8  9]
#  [10 11 12]]

# %%
print(arr1 + arr2)
# Out:
# [[ 8 10 12]
#  [14 16 18]]

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
scalar = 2

# %%
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr.shape)
# Out:
# (2, 3)

# %%
res1 = arr * scalar
print(res1)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]

# %%
arr_1d = np.array([10, 20, 30])
print(arr_1d)
# Out:
# [10 20 30]

# %%
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr_1d.shape)
# Out:
# (3,)

# %%
print(arr.shape)
# Out:
# (2, 3)

# %%
# [[10 20 30]
#  [10 20 30]]
print(arr + arr_1d)
# Out:
# [[11 22 33]
#  [14 25 36]]

# %%
arr_2d_1 = np.array([[10], [20]])
print(arr_2d_1)
# Out:
# [[10]
#  [20]]

# %%
print(arr_2d_1.shape)
# Out:
# (2, 1)

# %%
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr.shape)
# Out:
# (2, 3)

# %%
# [
#     [10][10][10]
#     [20][20][20]
# ]
print(arr * arr_2d_1)
# Out:
# [[ 10  20  30]
#  [ 80 100 120]]

# %%
arr_error = np.array([[1, 2], [3, 4], [5, 6]])
print(arr_error.shape)
# Out:
# (3, 2)

# %%
print(arr.shape)
# Out:
# (2, 3)

# %%
print(arr + arr_error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(arr + arr_error)
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,2)
