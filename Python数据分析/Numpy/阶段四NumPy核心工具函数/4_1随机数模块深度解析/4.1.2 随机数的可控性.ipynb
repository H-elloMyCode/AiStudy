# %%
import numpy as np

# %%
np.random.seed(888)

print(np.random.randint(1, 10, (2, 2)))
# Out:
# [[7 4]
#  [8 2]]

# %%
np.random.seed(888)

print(np.random.randint(1, 10, (2, 2)))
# Out:
# [[7 4]
#  [8 2]]

# %%
print(np.random.randint(1, 10, (2, 2)))
# Out:
# [[1 1]
#  [4 1]]

# %%
rng1 = np.random.default_rng(888)
rng2 = np.random.default_rng(999)

print(rng1.random((1, 2)))
print(rng2.random((1, 2)))

rng1_again = np.random.default_rng(888)
print(rng1_again.random((1, 2)))
# Out:
# [[0.39138063 0.02749503]]
# [[0.77882502 0.17224863]]
# [[0.39138063 0.02749503]]

# %%
# Out:
# [[0.68607168 0.51452038]]

# %%
print(np.__version__)
# Out:
# 2.4.1

# %%
# Out:
# [[0.92081192 0.16227386]]

# %%
rng3 = np.random.default_rng()

print(rng3.integers(1, 10, (2, 2)))
# Out:
# [[7 3]
#  [5 1]]

# %%
print(rng3.randint(1, 10, (2, 3)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 print(rng3.randint(1, 10, (2, 3)))
#
# AttributeError: 'numpy.random._generator.Generator' object has no attribute 'randint'
