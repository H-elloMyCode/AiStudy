# %%
import numpy as np

# %%
arr1 = np.array([[1, 2, 3], [4, 5, 6]])
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr2 = np.array([[10, 20, 30], [40, 50, 60]])
print(arr2)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
scalar = 2
print(scalar)
# Out:
# 2

# %%
print(arr1 + arr2)
# Out:
# [[11 22 33]
#  [44 55 66]]

# %%
print(np.add(arr1, arr2))
# Out:
# [[11 22 33]
#  [44 55 66]]

# %%
print(arr1 * scalar)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]

# %%
print(np.multiply(arr1, scalar))
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]

# %%
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr1 ** 2)
# Out:
# [[ 1  4  9]
#  [16 25 36]]

# %%
print(np.power(arr1, scalar))
# Out:
# [[ 1  4  9]
#  [16 25 36]]

# %%
print(arr2 % arr1)
# Out:
# [[0 0 0]
#  [0 0 0]]

# %%
print(np.mod(arr2, arr1))
# Out:
# [[0 0 0]
#  [0 0 0]]

# %%
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr2)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
print(np.sqrt(arr1))
# Out:
# [[1.         1.41421356 1.73205081]
#  [2.         2.23606798 2.44948974]]

# %%
print(np.sin(arr1))
# Out:
# [[ 0.84147098  0.90929743  0.14112001]
#  [-0.7568025  -0.95892427 -0.2794155 ]]

# %%
print(np.exp(arr1))
# Out:
# [[  2.71828183   7.3890561   20.08553692]
#  [ 54.59815003 148.4131591  403.42879349]]

# %%
print(np.abs(np.array([-1, -2])))
# Out:
# [1 2]

# %%
print(arr1 > 3)
# Out:
# [[False False False]
#  [ True  True  True]]

# %%
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr2)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
print(np.greater(arr1, 3))
# Out:
# [[False False False]
#  [ True  True  True]]

# %%
print(arr1 == arr2 / 10)
# Out:
# [[ True  True  True]
#  [ True  True  True]]

# %%
print(np.equal(arr1, arr2 / 10))
# Out:
# [[ True  True  True]
#  [ True  True  True]]

# %%
print(arr2 <= 50)
# Out:
# [[ True  True  True]
#  [ True  True False]]

# %%
print(np.less_equal(arr2, 50))
# Out:
# [[ True  True  True]
#  [ True  True False]]

# %%
print(arr1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(arr2)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
print((arr1 > 2) & (arr1 < 5))
# Out:
# [[False False  True]
#  [ True False False]]

# %%
print((arr1 < 2) | (arr1 > 5))
# Out:
# [[ True False False]
#  [False False  True]]

# %%
print(~(arr1 > 3))
# Out:
# [[ True  True  True]
#  [False False False]]

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

# %%
print(arr1)
# Out:
# [1 2 3]

# %%
print(arr2)
# Out:
# [4 5 6]

# %%
out_arr = np.empty(3)
print(out_arr)
# Out:
# [ 2.15863353e-288  6.74038442e-312 -0.00000000e+000]

# %%
np.add(arr1, arr2, out=out_arr)
# Out:
# array([5., 7., 9.])

# %%
print(out_arr)
# Out:
# [5. 7. 9.]
