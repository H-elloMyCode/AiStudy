# %%
import numpy as np

# %%
arr = np.array([1, 2, 3])

# %%
arr
# Out:
# array([1, 2, 3])

# %%
print(arr)
# Out:
# [1 2 3]

# %%
arr.ndim
# Out:
# 1

# %%
arr.shape
# Out:
# (3,)

# %%
arr.size
# Out:
# 3

# %%
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr2.ndim
# Out:
# 2

# %%
arr2.shape
# Out:
# (2, 3)

# %%
arr2.size
# Out:
# 6

# %%
arr3 = np.array([1, 2, "3"])

# %%
print(arr3)
# Out:
# ['1' '2' '3']

# %%
arr3.dtype
# Out:
# dtype('<U21')

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr2.dtype
# Out:
# dtype('int64')

# %%
tuple1 = (1,)
print(tuple1)
# Out:
# (1,)

# %%
tuple1 = (1)
print(tuple1)
# Out:
# 1
