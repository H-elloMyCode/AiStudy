# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(arr.ndim)
# Out:
# 1

# %%
print(arr.shape)
# Out:
# (5,)

# %%
print(arr.size)
# Out:
# 5

# %%
print(arr.dtype)
# Out:
# int64

# %%
arr2 = np.array([1.0, 2.0])
print(arr2.dtype)
# Out:
# float64

# %%
print(arr.itemsize)
# Out:
# 8

# %%
print(arr2.itemsize)
# Out:
# 8

# %%
print(arr.nbytes)
# Out:
# 40

# %%
print(arr2.nbytes)
# Out:
# 16
