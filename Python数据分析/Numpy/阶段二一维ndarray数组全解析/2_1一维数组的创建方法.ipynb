# %% [markdown]
# ##### 2.1.1 从 python 原生结构转换

# %%
import numpy as np

# %%
arr1 = np.array([1, 2, 3, 4, 5])
print(arr1)
# Out:
# [1 2 3 4 5]

# %%
arr2 = np.array((6, 7, 8, 9))
print(arr2)
# Out:
# [6 7 8 9]

# %%
arr3 = np.array(range(1, 6))
print(arr3)
# Out:
# [1 2 3 4 5]

# %%
arr1.ndim
# Out:
# 1

# %%
arr1.dtype
# Out:
# dtype('int64')

# %%
arr1.shape
# Out:
# (5,)

# %%
arr1.size
# Out:
# 5

# %%
arr4 = np.array([1, 2, "3"])
print(arr4)
# Out:
# ['1' '2' '3']

# %%
arr5 = np.array([1.0, 2.0, 3.4])
print(arr5)
# Out:
# [1.  2.  3.4]

# %%
arr5.dtype
# Out:
# dtype('float64')

# %%
arr6 = np.array([1, 2, 3.4])
print(arr6)
# Out:
# [1.  2.  3.4]
