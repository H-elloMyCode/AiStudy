# %%
import numpy as np

# %%
print(np.array([1, 2, 3], dtype=float))
# Out:
# [1. 2. 3.]

# %%
print(np.zeros(4, dtype=int))
# Out:
# [0 0 0 0]

# %%
print(np.zeros(4))
# Out:
# [0. 0. 0. 0.]

# %%
print(np.random.randint(1, 5, 3, dtype=int))
# Out:
# [4 2 4]

# %%
arr_float = np.array([1.2, 2.9, -3.5])
arr_int = np.array([0, 1, -2])

print(arr_float)
print(arr_int)
# Out:
# [ 1.2  2.9 -3.5]
# [ 0  1 -2]

# %%
arr_float.astype(int)
# Out:
# array([ 1,  2, -3])

# %%
arr_int.astype(float)
# Out:
# array([ 0.,  1., -2.])

# %%
arr_int.astype(bool)
# Out:
# array([False,  True,  True])

# %%
np.array([True, False]).astype(int)
# Out:
# array([1, 0])
