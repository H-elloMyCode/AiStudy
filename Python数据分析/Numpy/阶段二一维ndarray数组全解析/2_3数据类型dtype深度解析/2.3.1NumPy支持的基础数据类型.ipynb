# %%
import numpy as np

# %%
arr_int = np.array([1, 2, -3])
print(arr_int)
# Out:
# [ 1  2 -3]

# %%
arr_int.dtype
# Out:
# dtype('int64')

# %%
arr_float = np.array([1.2, 3.0])
print(arr_float)
# Out:
# [1.2 3. ]

# %%
arr_float.dtype
# Out:
# dtype('float64')

# %%
arr_bool = np.array([True, False])
print(arr_bool)
# Out:
# [ True False]

# %%
arr_bool.dtype
# Out:
# dtype('bool')

# %%
arr1 = np.array([1, 2.5, 3])
print(arr1)
# Out:
# [1.  2.5 3. ]

# %%
arr1.dtype
# Out:
# dtype('float64')
