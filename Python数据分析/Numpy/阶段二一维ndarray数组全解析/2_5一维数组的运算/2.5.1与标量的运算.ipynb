# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
num = 2
print(num)
# Out:
# 2

# %%
print(arr + num)
# Out:
# [3 4 5 6 7]

# %%
print(arr - num)
# Out:
# [-1  0  1  2  3]

# %%
print(arr * num)
# Out:
# [ 2  4  6  8 10]

# %%
print(arr / num)
# Out:
# [0.5 1.  1.5 2.  2.5]

# %%
print(arr ** num)
# Out:
# [ 1  4  9 16 25]

# %%
print(arr // num)
# Out:
# [0 1 1 2 2]

# %%
print(arr % num)
# Out:
# [1 0 1 0 1]

# %%
arr = np.array([1, 2, 3])
print(arr)
# Out:
# [1 2 3]

# %%
print(10 - arr)
# Out:
# [9 8 7]

# %%
print(2 * arr)
# Out:
# [2 4 6]

# %%
new_arr = arr + 2
print(new_arr)
print(arr)
# Out:
# [3 4 5]
# [1 2 3]
