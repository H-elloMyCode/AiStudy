# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5, 5, 8])
print(arr)
# Out:
# [1 2 3 4 5 5 8]

# %%
print(arr.sum())
# Out:
# 28

# %%
print(arr.mean())
# Out:
# 4.0

# %%
print(arr.max())
# Out:
# 8

# %%
print(arr.min())
# Out:
# 1

# %%
print(arr.std())
# Out:
# 2.138089935299395

# %%
print(arr.var())
# Out:
# 4.571428571428571

# %%
print(arr.size)
# Out:
# 7

# %%
print(arr)
# Out:
# [1 2 3 4 5 5 8]

# %%
print(arr.argmax())
# Out:
# 6

# %%
print(arr.argmin())
# Out:
# 0

# %%
arr = np.array([1, 2, 2, 3, 3, 3, 5])
print(arr)
# Out:
# [1 2 2 3 3 3 5]

# %%
print(np.unique(arr))
# Out:
# [1 2 3 5]
