# %%
import numpy as np

# %%
print(np.random.rand(5))
# Out:
# [0.08402058 0.50504784 0.99885133 0.22649899 0.7902354 ]

# %%
print(np.random.randint(1, 10, 4))
# Out:
# [9 4 4 3]

# %%
print(np.random.normal(size=6))
# Out:
# [ 0.49745347  0.68894649  1.90953812 -0.15817278 -0.4967038  -0.84698793]

# %%
print(np.random.rand(10))
# Out:
# [0.40063163 0.99513816 0.17756418 0.9625969  0.41925027 0.42405245
#  0.46314887 0.37372315 0.4655081  0.03516826]

# %%
np.random.seed(12)
print(np.random.rand(10))
# Out:
# [0.15416284 0.7400497  0.26331502 0.53373939 0.01457496 0.91874701
#  0.90071485 0.03342143 0.95694934 0.13720932]

# %%
np.random.seed(12)
print(np.random.rand(10))
# Out:
# [0.15416284 0.7400497  0.26331502 0.53373939 0.01457496 0.91874701
#  0.90071485 0.03342143 0.95694934 0.13720932]
