# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [5, 1, 4])
plt.title("IDLE 测试")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 3))

plt.plot([1, 2, 3], [2, 5, 3])
plt.title('测试')
plt.xlabel('x')
plt.ylabel('y')

plt.show()
