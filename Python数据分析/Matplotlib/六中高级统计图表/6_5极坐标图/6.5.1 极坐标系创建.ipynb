# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams["font.family"] = ["DejaVu Sans", "SimHei", "Microsoft YaHei"]
plt.rcParams['axes.unicode_minus'] = False

# %%
fig = plt.figure(figsize=(6, 6))

ax = fig.add_subplot(111, projection='polar')

theta = np.linspace(0, 2 * np.pi, 100)
# 这就是三叶玫瑰线的核心公式
r = np.sin(3 * theta)

ax.plot(theta, r, color='blue', linewidth=2)
ax.set_title("极坐标系基础", fontsize=14, pad=20)

plt.tight_layout()

plt.show()

# %%
theta = np.linspace(0, 2 * np.pi, 100)
# print(theta)

# %%
fig = plt.figure(figsize=(6, 6))

ax = fig.add_subplot(111, projection='polar')

theta = np.linspace(0, 2 * np.pi, 100)
r = np.sin(10 * theta)

ax.plot(theta, r, color='blue', linewidth=2)
ax.set_title("极坐标系基础", fontsize=14, pad=20)

plt.tight_layout()

plt.show()

# %%
fig = plt.figure(figsize=(6, 6))

ax = fig.add_subplot(111, projection='polar')

theta = np.linspace(0, 2 * np.pi, 100)
r = np.sin(5 * theta)

ax.plot(theta, r, color='blue', linewidth=2)
ax.set_title("极坐标系基础", fontsize=14, pad=20)

plt.tight_layout()

plt.show()
