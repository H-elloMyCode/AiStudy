# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["font.family"] = ["DejaVu Sans", "SimHei", "Microsoft YaHei"]
plt.rcParams['axes.unicode_minus'] = False

# %%
x = [1, 2, 3, 4, 5]
y = [3, 1, 4, 2, 5]

# %%
fig, ax = plt.subplots(figsize=(7, 4))

ax.plot(x, y, marker='o', linewidth=2)

ax.set_xlim(0, 6)
ax.set_ylim(0, 6)

# 标签与标题
ax.set_xlabel("X轴数据", fontsize=12)
ax.set_ylabel("Y轴数据", fontsize=12)
ax.set_title("坐标轴范围设置", fontsize=14, pad=10)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 4))

ax.plot(x, y, marker='o', linewidth=2)

# ax.set_xlim(0, 6)
# ax.set_ylim(0, 6)

# 标签与标题
ax.set_xlabel("X轴数据", fontsize=12)
ax.set_ylabel("Y轴数据", fontsize=12)
ax.set_title("坐标轴范围设置", fontsize=14, pad=10)

plt.show()
