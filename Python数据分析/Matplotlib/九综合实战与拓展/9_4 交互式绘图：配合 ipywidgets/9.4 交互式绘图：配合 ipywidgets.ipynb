# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact

# %%
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

# %%
@interact(freq=(1, 5, 0.2), amp=(0.5, 4, 0.1))
def plot_sine(freq=2, amp=1):
    x = np.linspace(0, 2 * np.pi, 200)
    y = amp * np.sin(freq * x)

    plt.figure(figsize=(7, 4))
    plt.plot(x, y, lw=2, color='teal')
    plt.ylim(-5, 5)
    plt.title(f'频率={freq}，振幅={amp}')
    plt.grid(alpha=0.3)
    plt.show()
# Out:
# interactive(children=(FloatSlider(value=2.0, description='freq', max=5.0, min=1.0, step=0.2), FloatSlider(valu…
