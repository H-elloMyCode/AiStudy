# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams["font.family"] = ["DejaVu Sans", "SimHei", "Microsoft YaHei"]
plt.rcParams['axes.unicode_minus'] = False

# %%
x = [1, 2, 3, 4, 5]
y = [2, 3, 1, 4, 2]

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, linewidth=2)
plt.title('图片保存测试')

plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, linewidth=2)
plt.title('图片保存测试')

plt.savefig("test.png", dpi=300, bbox_inches='tight')

plt.close()
print("保存成功!")

# plt.show()
# Out:
# 保存成功!

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, linewidth=2)
plt.title('图片保存测试')

plt.savefig("test.jpg", dpi=300, bbox_inches='tight')

plt.close()
print("保存成功!")
# Out:
# 保存成功!

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, linewidth=2)
plt.title('图片保存测试')

plt.savefig("test.pdf", dpi=300, bbox_inches='tight')

plt.close()
print("保存成功!")
# Out:
# 保存成功!

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, linewidth=2)
plt.title('图片保存测试')

plt.savefig("test.svg", dpi=300, bbox_inches='tight')

plt.close()
print("保存成功!")
# Out:
# 保存成功!

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, linewidth=2)
plt.title('图片保存测试')

plt.show()
plt.savefig("test1.svg", dpi=300, bbox_inches='tight')

plt.close()
print("保存成功!")
# Out:
# 保存成功!

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, linewidth=2)
plt.title('图片保存测试')

plt.show()
plt.savefig("test1.png", dpi=300, bbox_inches='tight')

plt.close()
print("保存成功!")
# Out:
# 保存成功!

# %%
plt.figure(figsize=(6, 4))
plt.plot(x, y, linewidth=2)
plt.title('图片保存测试')


plt.savefig("test1.png", dpi=300, bbox_inches='tight')
plt.show()
plt.close()
print("保存成功!")
# Out:
# 保存成功!
