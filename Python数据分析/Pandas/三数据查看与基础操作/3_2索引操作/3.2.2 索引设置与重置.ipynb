# %%
import pandas as pd

# %%
file_path = r'index_operate.csv'

df = pd.read_csv(file_path, encoding='utf-8')
df
# Out:
#    订单ID  用户ID 商品名称  城市  消费金额
# 0  1001   201   手机  北京  2999
# 1  1002   202   耳机  上海   399
# 2  1003   201   卫衣  北京   199
# 3  1004   203   水杯  广州    59
# 4  1005   202   键盘  上海   899

# %%
df.head(3)
# Out:
#    订单ID  用户ID 商品名称  城市  消费金额
# 0  1001   201   手机  北京  2999
# 1  1002   202   耳机  上海   399
# 2  1003   201   卫衣  北京   199

# %%
df
# Out:
#    订单ID  用户ID 商品名称  城市  消费金额
# 0  1001   201   手机  北京  2999
# 1  1002   202   耳机  上海   399
# 2  1003   201   卫衣  北京   199
# 3  1004   203   水杯  广州    59
# 4  1005   202   键盘  上海   899

# %%
df_order_index = df.set_index('订单ID')
df_order_index
# Out:
#       用户ID 商品名称  城市  消费金额
# 订单ID
# 1001   201   手机  北京  2999
# 1002   202   耳机  上海   399
# 1003   201   卫衣  北京   199
# 1004   203   水杯  广州    59
# 1005   202   键盘  上海   899

# %%
print(type(df_order_index.index))
# Out:
# <class 'pandas.RangeIndex'>

# %%
print(df_order_index.index.to_list())
# Out:
# [1001, 1002, 1003, 1004, 1005]

# %%
df_multi_index = df.set_index(['用户ID', '订单ID'])
df_multi_index
# Out:
#           商品名称  城市  消费金额
# 用户ID 订单ID
# 201  1001   手机  北京  2999
# 202  1002   耳机  上海   399
# 201  1003   卫衣  北京   199
# 203  1004   水杯  广州    59
# 202  1005   键盘  上海   899

# %%
print(type(df_multi_index.index))
# Out:
# <class 'pandas.MultiIndex'>

# %%
print(df_multi_index.index.to_list())
# Out:
# [(201, 1001), (202, 1002), (201, 1003), (203, 1004), (202, 1005)]

# %%
df
# Out:
#    订单ID  用户ID 商品名称  城市  消费金额
# 0  1001   201   手机  北京  2999
# 1  1002   202   耳机  上海   399
# 2  1003   201   卫衣  北京   199
# 3  1004   203   水杯  广州    59
# 4  1005   202   键盘  上海   899

# %%
df_read_index = pd.read_csv(
    file_path,
    encoding='utf-8',
    index_col='订单ID'
)

df_read_index
# Out:
#       用户ID 商品名称  城市  消费金额
# 订单ID
# 1001   201   手机  北京  2999
# 1002   202   耳机  上海   399
# 1003   201   卫衣  北京   199
# 1004   203   水杯  广州    59
# 1005   202   键盘  上海   899

# %%
df_order_index
# Out:
#       用户ID 商品名称  城市  消费金额
# 订单ID
# 1001   201   手机  北京  2999
# 1002   202   耳机  上海   399
# 1003   201   卫衣  北京   199
# 1004   203   水杯  广州    59
# 1005   202   键盘  上海   899

# %%
df_reset1 = df_order_index.reset_index()
df_reset1
# Out:
#    订单ID  用户ID 商品名称  城市  消费金额
# 0  1001   201   手机  北京  2999
# 1  1002   202   耳机  上海   399
# 2  1003   201   卫衣  北京   199
# 3  1004   203   水杯  广州    59
# 4  1005   202   键盘  上海   899

# %%
df_multi_index
# Out:
#           商品名称  城市  消费金额
# 用户ID 订单ID
# 201  1001   手机  北京  2999
# 202  1002   耳机  上海   399
# 201  1003   卫衣  北京   199
# 203  1004   水杯  广州    59
# 202  1005   键盘  上海   899

# %%
print(df_multi_index.index.to_list())
# Out:
# [(201, 1001), (202, 1002), (201, 1003), (203, 1004), (202, 1005)]

# %%
df_reset2 = df_multi_index.reset_index()
df_reset2
# Out:
#    用户ID  订单ID 商品名称  城市  消费金额
# 0   201  1001   手机  北京  2999
# 1   202  1002   耳机  上海   399
# 2   201  1003   卫衣  北京   199
# 3   203  1004   水杯  广州    59
# 4   202  1005   键盘  上海   899

# %%
df_order_index
# Out:
#       用户ID 商品名称  城市  消费金额
# 订单ID
# 1001   201   手机  北京  2999
# 1002   202   耳机  上海   399
# 1003   201   卫衣  北京   199
# 1004   203   水杯  广州    59
# 1005   202   键盘  上海   899

# %%
df_reset_drop = df_order_index.reset_index(drop=True)
df_reset_drop
# Out:
#    用户ID 商品名称  城市  消费金额
# 0   201   手机  北京  2999
# 1   202   耳机  上海   399
# 2   201   卫衣  北京   199
# 3   203   水杯  广州    59
# 4   202   键盘  上海   899

# %%
df
# Out:
#    订单ID  用户ID 商品名称  城市  消费金额
# 0  1001   201   手机  北京  2999
# 1  1002   202   耳机  上海   399
# 2  1003   201   卫衣  北京   199
# 3  1004   203   水杯  广州    59
# 4  1005   202   键盘  上海   899

# %%
df_order_index
# Out:
#       用户ID 商品名称  城市  消费金额
# 订单ID
# 1001   201   手机  北京  2999
# 1002   202   耳机  上海   399
# 1003   201   卫衣  北京   199
# 1004   203   水杯  广州    59
# 1005   202   键盘  上海   899

# %%
print(df['订单ID'].is_unique)
# Out:
# True
