# %%
import pandas as pd

# %%
file_path = r'column_rename.csv'

df = pd.read_csv(file_path, encoding='utf-8')
df
# Out:
#    订单ID  用户ID  姓名  城市  消费金额        下单时间
# 0  1001   201  张三  北京  2999  2024-01-01
# 1  1002   202  李四  上海   399  2024-01-01
# 2  1003   201  张三  北京   199  2024-01-02
# 3  1004   203  王五  广州    59  2024-01-02
# 4  1005   202  李四  上海   899  2024-01-03

# %%
print(df.columns.tolist())
# Out:
# ['订单ID', '用户ID', '姓名', '城市', '消费金额', '下单时间']

# %%
df.rename(
    columns={
        '订单ID': 'order_id',
        '消费金额': 'payment',
        '下单时间': 'order_time'
    },
    inplace=True
)

df
# Out:
#    order_id  用户ID  姓名  城市  payment  order_time
# 0      1001   201  张三  北京     2999  2024-01-01
# 1      1002   202  李四  上海      399  2024-01-01
# 2      1003   201  张三  北京      199  2024-01-02
# 3      1004   203  王五  广州       59  2024-01-02
# 4      1005   202  李四  上海      899  2024-01-03

# %%
print(df.columns.tolist())
# Out:
# ['order_id', '用户ID', '姓名', '城市', 'payment', 'order_time']

# %%
df
# Out:
#    order_id  用户ID  姓名  城市  payment  order_time
# 0      1001   201  张三  北京     2999  2024-01-01
# 1      1002   202  李四  上海      399  2024-01-01
# 2      1003   201  张三  北京      199  2024-01-02
# 3      1004   203  王五  广州       59  2024-01-02
# 4      1005   202  李四  上海      899  2024-01-03

# %%
df.rename(columns={'用户ID': 'user_id'}, inplace=True)
df
# Out:
#    order_id  user_id  姓名  城市  payment  order_time
# 0      1001      201  张三  北京     2999  2024-01-01
# 1      1002      202  李四  上海      399  2024-01-01
# 2      1003      201  张三  北京      199  2024-01-02
# 3      1004      203  王五  广州       59  2024-01-02
# 4      1005      202  李四  上海      899  2024-01-03

# %%
print(df.columns.tolist())
# Out:
# ['order_id', 'user_id', '姓名', '城市', 'payment', 'order_time']

# %%
df
# Out:
#    order_id  user_id  姓名  城市  payment  order_time
# 0      1001      201  张三  北京     2999  2024-01-01
# 1      1002      202  李四  上海      399  2024-01-01
# 2      1003      201  张三  北京      199  2024-01-02
# 3      1004      203  王五  广州       59  2024-01-02
# 4      1005      202  李四  上海      899  2024-01-03

# %%
df_all_rename = df.copy()

# %%
df_all_rename
# Out:
#    order_id  user_id  姓名  城市  payment  order_time
# 0      1001      201  张三  北京     2999  2024-01-01
# 1      1002      202  李四  上海      399  2024-01-01
# 2      1003      201  张三  北京      199  2024-01-02
# 3      1004      203  王五  广州       59  2024-01-02
# 4      1005      202  李四  上海      899  2024-01-03

# %%
df_all_rename.columns = ['订单编号', '用户编号', '姓名', '城市', '支付金额', '下单日期']

# %%
df_all_rename
# Out:
#    订单编号  用户编号  姓名  城市  支付金额        下单日期
# 0  1001   201  张三  北京  2999  2024-01-01
# 1  1002   202  李四  上海   399  2024-01-01
# 2  1003   201  张三  北京   199  2024-01-02
# 3  1004   203  王五  广州    59  2024-01-02
# 4  1005   202  李四  上海   899  2024-01-03

# %%
print(df_all_rename.columns.tolist())
# Out:
# ['订单编号', '用户编号', '姓名', '城市', '支付金额', '下单日期']

# %%
df_space = df.copy()

# %%
df_space
# Out:
#    order_id  user_id  姓名  城市  payment  order_time
# 0      1001      201  张三  北京     2999  2024-01-01
# 1      1002      202  李四  上海      399  2024-01-01
# 2      1003      201  张三  北京      199  2024-01-02
# 3      1004      203  王五  广州       59  2024-01-02
# 4      1005      202  李四  上海      899  2024-01-03

# %%
df_space.columns = [' order_id ', ' user_id ', ' 姓名 ', ' 城市 ', ' payment ', ' order_time ']

# %%
df_space
# Out:
#    order_id   user_id  姓名  城市   payment  order_time
# 0       1001       201  张三  北京      2999  2024-01-01
# 1       1002       202  李四  上海       399  2024-01-01
# 2       1003       201  张三  北京       199  2024-01-02
# 3       1004       203  王五  广州        59  2024-01-02
# 4       1005       202  李四  上海       899  2024-01-03

# %%
print(df_space.columns.tolist())
# Out:
# [' order_id ', ' user_id ', ' 姓名 ', ' 城市 ', ' payment ', ' order_time ']

# %%
df_space.columns = df_space.columns.str.strip()

# %%
print(df_space.columns.tolist())
# Out:
# ['order_id', 'user_id', '姓名', '城市', 'payment', 'order_time']
