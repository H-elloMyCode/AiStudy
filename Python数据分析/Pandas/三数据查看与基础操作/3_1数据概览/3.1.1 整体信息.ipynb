# %%
import pandas as pd

# %%
file_path = r'user_data.csv'
df = pd.read_csv(
    file_path,
    encoding='utf-8',
    parse_dates=['注册时间']
)

df
# Out:
#    用户ID  姓名    年龄   城市       注册时间    消费金额 会员等级
# 0   101  张三  25.0   北京 2024-01-01   899.5  VIP
# 1   102  李四   NaN   上海 2024-01-02     NaN   普通
# 2   103  王五  30.0   广州 2024-01-03  1299.0  VIP
# 3   104  赵六  35.0  NaN 2024-01-04   599.9   普通
# 4   105  钱七  28.0   深圳        NaT   799.8  VIP

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   用户ID    5 non-null      int64
#  1   姓名      5 non-null      str
#  2   年龄      4 non-null      float64
#  3   城市      4 non-null      str
#  4   注册时间    4 non-null      datetime64[us]
#  5   消费金额    4 non-null      float64
#  6   会员等级    5 non-null      str
# dtypes: datetime64[us](1), float64(2), int64(1), str(3)
# memory usage: 412.0 bytes

# %%
df.shape
# Out:
# (5, 7)

# %%
df.columns.to_list()
# Out:
# ['用户ID', '姓名', '年龄', '城市', '注册时间', '消费金额', '会员等级']

# %%
print(df.isnull().sum().sum())
# Out:
# 4
