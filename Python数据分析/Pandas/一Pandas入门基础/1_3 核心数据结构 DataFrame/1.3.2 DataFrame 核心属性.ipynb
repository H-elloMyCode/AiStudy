# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    {
        '姓名': ['张三', '李四', '王五', '赵六'],
        '年龄': [20, 25, None, 30],
        '成绩': [85.5, 90.0, 78.0, np.nan]
    },
    index=['A', 'B', 'C', 'D']
)
print(df)
# Out:
#    姓名    年龄    成绩
# A  张三  20.0  85.5
# B  李四  25.0  90.0
# C  王五   NaN  78.0
# D  赵六  30.0   NaN

# %%
print(df.columns)
# Out:
# Index(['姓名', '年龄', '成绩'], dtype='str')

# %%
print(df.index)
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='str')

# %%
print(df.dtypes)
# Out:
# 姓名        str
# 年龄    float64
# 成绩    float64
# dtype: object

# %%
print(df.shape)
# Out:
# (4, 3)

# %%
print(df.values)
# Out:
# [['张三' 20.0 85.5]
#  ['李四' 25.0 90.0]
#  ['王五' nan 78.0]
#  ['赵六' 30.0 nan]]

# %%
print(type(df.values))
# Out:
# <class 'numpy.ndarray'>

# %%
print(df.isnull())
# Out:
#       姓名     年龄     成绩
# A  False  False  False
# B  False  False  False
# C  False   True  False
# D  False  False   True

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, A to D
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   姓名      4 non-null      str
#  1   年龄      3 non-null      float64
#  2   成绩      3 non-null      float64
# dtypes: float64(2), str(1)
# memory usage: 128.0+ bytes
# None

# %%
print(df)
# Out:
#    姓名    年龄    成绩
# A  张三  20.0  85.5
# B  李四  25.0  90.0
# C  王五   NaN  78.0
# D  赵六  30.0   NaN

# %%
df
# Out:
#    姓名    年龄    成绩
# A  张三  20.0  85.5
# B  李四  25.0  90.0
# C  王五   NaN  78.0
# D  赵六  30.0   NaN

# %%
print(df.describe())
# Out:
#          年龄         成绩
# count   3.0   3.000000
# mean   25.0  84.500000
# std     5.0   6.062178
# min    20.0  78.000000
# 25%    22.5  81.750000
# 50%    25.0  85.500000
# 75%    27.5  87.750000
# max    30.0  90.000000

# %%
print(df.isnull().sum())
# Out:
# 姓名    0
# 年龄    1
# 成绩    1
# dtype: int64

# %%
print(df.isnull().sum().sum())
# Out:
# 2
