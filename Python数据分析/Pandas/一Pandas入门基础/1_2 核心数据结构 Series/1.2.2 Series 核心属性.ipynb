# %%
import pandas as pd

# %%
s = pd.Series([100, 200, 300, None],
              index=['北京', '上海', '四川', '深圳'],
              dtype='float64')

print(s)
# Out:
# 北京    100.0
# 上海    200.0
# 四川    300.0
# 深圳      NaN
# dtype: float64

# %%
print(s.values)
# Out:
# [100. 200. 300.  nan]

# %%
print(s.index)
# Out:
# Index(['北京', '上海', '四川', '深圳'], dtype='str')

# %%
print(s.dtype)
# Out:
# float64

# %%
print(s.shape)
# Out:
# (4,)

# %%
print(s.isnull())
# Out:
# 北京    False
# 上海    False
# 四川    False
# 深圳     True
# dtype: bool

# %%
print(s.notnull())
# Out:
# 北京     True
# 上海     True
# 四川     True
# 深圳    False
# dtype: bool

# %%
print(s.count())
# Out:
# 3

# %%
print(s.unique())
# Out:
# [100. 200. 300.  nan]

# %%
s2 = pd.Series([100, 200, 300, None, 200],
              index=['北京', '上海', '四川', '深圳', '广州'],
              dtype='float64')
print(s2)
# Out:
# 北京    100.0
# 上海    200.0
# 四川    300.0
# 深圳      NaN
# 广州    200.0
# dtype: float64

# %%
print(s2.unique())
# Out:
# [100. 200. 300.  nan]

# %%
print(s.value_counts())
# Out:
# 100.0    1
# 200.0    1
# 300.0    1
# Name: count, dtype: int64

# %%
print(s2.value_counts())
# Out:
# 200.0    2
# 100.0    1
# 300.0    1
# Name: count, dtype: int64

# %%
print(s.count())
# Out:
# 3

# %%
print(len(s))
# Out:
# 4
