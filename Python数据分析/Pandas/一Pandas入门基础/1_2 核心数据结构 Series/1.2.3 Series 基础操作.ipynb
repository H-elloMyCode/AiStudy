# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([100, 200, 300, 400],
              index=['北京', '上海', '广州', '深圳'])
print(s)
# Out:
# 北京    100
# 上海    200
# 广州    300
# 深圳    400
# dtype: int64

# %%
print(s['上海'])
# Out:
# 200

# %%
print(s.loc['上海'])
# Out:
# 200

# %%
print(s[['北京', '深圳']])
# Out:
# 北京    100
# 深圳    400
# dtype: int64

# %%
print(s.iloc[1])
# Out:
# 200

# %%
print(s.iloc[1:3])
# Out:
# 上海    200
# 广州    300
# dtype: int64

# %%
print(s[1:3])
# Out:
# 上海    200
# 广州    300
# dtype: int64

# %%
print(s[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\anaconda3\envs\Pandas\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(s[1])
#
# File E:\anaconda3\envs\Pandas\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
# ...

# %%
print(s)
# Out:
# 北京    100
# 上海    200
# 广州    300
# 深圳    400
# dtype: int64

# %%
print(s[s > 200])
# Out:
# 广州    300
# 深圳    400
# dtype: int64

# %%
print(s[(s > 100) & (s < 400)])
# Out:
# 上海    200
# 广州    300
# dtype: int64

# %%
s['北京'] = 150

# %%
print(s)
# Out:
# 北京    150
# 上海    200
# 广州    300
# 深圳    400
# dtype: int64

# %%
s[s > 300] = 350

# %%
print(s)
# Out:
# 北京    150
# 上海    200
# 广州    300
# 深圳    350
# dtype: int64

# %%
s_nan = pd.Series([10, 20, None, 40], index=['a', 'b', 'c', 'd'])
print(s_nan)
# Out:
# a    10.0
# b    20.0
# c     NaN
# d    40.0
# dtype: float64

# %%
s_drop = s_nan.dropna()

# %%
print(s_drop)
# Out:
# a    10.0
# b    20.0
# d    40.0
# dtype: float64

# %%
print(s_nan)
# Out:
# a    10.0
# b    20.0
# c     NaN
# d    40.0
# dtype: float64

# %%
s_fill = s_nan.fillna(s_nan.mean())
print(s_fill)
# Out:
# a    10.000000
# b    20.000000
# c    23.333333
# d    40.000000
# dtype: float64

# %%
print(s)
# Out:
# 北京    150
# 上海    200
# 广州    300
# 深圳    350
# dtype: int64

# %%
s_replace = s.replace(200, 220)
print(s_replace)
# Out:
# 北京    150
# 上海    220
# 广州    300
# 深圳    350
# dtype: int64

# %%
print(s)
# Out:
# 北京    150
# 上海    200
# 广州    300
# 深圳    350
# dtype: int64

# %%
s_sort = s.sort_values(ascending=False)
print(s_sort)
# Out:
# 深圳    350
# 广州    300
# 上海    200
# 北京    150
# dtype: int64

# %%
print(s['四川'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\anaconda3\envs\Pandas\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '四川'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(s['四川'])
#
# ...
