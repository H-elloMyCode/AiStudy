# %%
import pandas as pd

# %%
file_path = r'query_filter.csv'

df = pd.read_csv(file_path, encoding='utf-8')

df
# Out:
#    订单ID 商品名称    单价  数量  城市    总价   品类   是否包邮        下单时间
# 0  1001   手机  2999   2  北京  5998   数码   True  2024-01-01
# 1  1002   耳机   399   5  上海  1995   数码  False  2024-01-02
# 2  1003   卫衣   199  10  广州  1990   服饰   True  2024-01-03
# 3  1004   水杯    59  20  深圳  1180  日用品  False  2024-01-04
# 4  1005   键盘   899   3  北京  2697   数码   True  2024-01-05
# 5  1006   鼠标    99   8  上海   792   数码  False  2024-01-06

# %%
df['下单时间'] = pd.to_datetime(df['下单时间'])
df
# Out:
#    订单ID 商品名称    单价  数量  城市    总价   品类   是否包邮       下单时间
# 0  1001   手机  2999   2  北京  5998   数码   True 2024-01-01
# 1  1002   耳机   399   5  上海  1995   数码  False 2024-01-02
# 2  1003   卫衣   199  10  广州  1990   服饰   True 2024-01-03
# 3  1004   水杯    59  20  深圳  1180  日用品  False 2024-01-04
# 4  1005   键盘   899   3  北京  2697   数码   True 2024-01-05
# 5  1006   鼠标    99   8  上海   792   数码  False 2024-01-06

# %%
print(len(df))
# Out:
# 6

# %%
df_q1 = df.query('单价 > 500')
df_q1
# Out:
#    订单ID 商品名称    单价  数量  城市    总价  品类  是否包邮       下单时间
# 0  1001   手机  2999   2  北京  5998  数码  True 2024-01-01
# 4  1005   键盘   899   3  北京  2697  数码  True 2024-01-05

# %%
df_q2 = df.query('城市  == "北京"')
df_q2
# Out:
#    订单ID 商品名称    单价  数量  城市    总价  品类  是否包邮       下单时间
# 0  1001   手机  2999   2  北京  5998  数码  True 2024-01-01
# 4  1005   键盘   899   3  北京  2697  数码  True 2024-01-05

# %%
df
# Out:
#    订单ID 商品名称    单价  数量  城市    总价   品类   是否包邮       下单时间
# 0  1001   手机  2999   2  北京  5998   数码   True 2024-01-01
# 1  1002   耳机   399   5  上海  1995   数码  False 2024-01-02
# 2  1003   卫衣   199  10  广州  1990   服饰   True 2024-01-03
# 3  1004   水杯    59  20  深圳  1180  日用品  False 2024-01-04
# 4  1005   键盘   899   3  北京  2697   数码   True 2024-01-05
# 5  1006   鼠标    99   8  上海   792   数码  False 2024-01-06

# %%
df_q3 = df.query('是否包邮 and 品类 == "数码" and 总价 > 2000')
df_q3
# Out:
#    订单ID 商品名称    单价  数量  城市    总价  品类  是否包邮       下单时间
# 0  1001   手机  2999   2  北京  5998  数码  True 2024-01-01
# 4  1005   键盘   899   3  北京  2697  数码  True 2024-01-05

# %%
df_q4 = df.query('城市 == "上海" or 数量 > 10 or 单价 < 100')
df_q4
# Out:
#    订单ID 商品名称   单价  数量  城市    总价   品类   是否包邮       下单时间
# 1  1002   耳机  399   5  上海  1995   数码  False 2024-01-02
# 3  1004   水杯   59  20  深圳  1180  日用品  False 2024-01-04
# 5  1006   鼠标   99   8  上海   792   数码  False 2024-01-06

# %%
df
# Out:
#    订单ID 商品名称    单价  数量  城市    总价   品类   是否包邮       下单时间
# 0  1001   手机  2999   2  北京  5998   数码   True 2024-01-01
# 1  1002   耳机   399   5  上海  1995   数码  False 2024-01-02
# 2  1003   卫衣   199  10  广州  1990   服饰   True 2024-01-03
# 3  1004   水杯    59  20  深圳  1180  日用品  False 2024-01-04
# 4  1005   键盘   899   3  北京  2697   数码   True 2024-01-05
# 5  1006   鼠标    99   8  上海   792   数码  False 2024-01-06

# %%
df_q5 = df.query('城市 in ["北京", "广州"]')
df_q5
# Out:
#    订单ID 商品名称    单价  数量  城市    总价  品类  是否包邮       下单时间
# 0  1001   手机  2999   2  北京  5998  数码  True 2024-01-01
# 2  1003   卫衣   199  10  广州  1990  服饰  True 2024-01-03
# 4  1005   键盘   899   3  北京  2697  数码  True 2024-01-05

# %%
df_q6 = df.query('品类 not in ["数码"]')
df_q6
# Out:
#    订单ID 商品名称   单价  数量  城市    总价   品类   是否包邮       下单时间
# 2  1003   卫衣  199  10  广州  1990   服饰   True 2024-01-03
# 3  1004   水杯   59  20  深圳  1180  日用品  False 2024-01-04

# %%
df
# Out:
#    订单ID 商品名称    单价  数量  城市    总价   品类   是否包邮       下单时间
# 0  1001   手机  2999   2  北京  5998   数码   True 2024-01-01
# 1  1002   耳机   399   5  上海  1995   数码  False 2024-01-02
# 2  1003   卫衣   199  10  广州  1990   服饰   True 2024-01-03
# 3  1004   水杯    59  20  深圳  1180  日用品  False 2024-01-04
# 4  1005   键盘   899   3  北京  2697   数码   True 2024-01-05
# 5  1006   鼠标    99   8  上海   792   数码  False 2024-01-06

# %%
price_threshold = 200
df_q7 = df.query('单价 > @price_threshold and 数量 < 5')
df_q7
# Out:
#    订单ID 商品名称    单价  数量  城市    总价  品类  是否包邮       下单时间
# 0  1001   手机  2999   2  北京  5998  数码  True 2024-01-01
# 4  1005   键盘   899   3  北京  2697  数码  True 2024-01-05

# %%
df_q8 = df.query('下单时间 >= "2024-01-04"')
df_q8
# Out:
#    订单ID 商品名称   单价  数量  城市    总价   品类   是否包邮       下单时间
# 3  1004   水杯   59  20  深圳  1180  日用品  False 2024-01-04
# 4  1005   键盘  899   3  北京  2697   数码   True 2024-01-05
# 5  1006   鼠标   99   8  上海   792   数码  False 2024-01-06

# %%
df_q9 = df.query('单价 * 数量 > 总价')
df_q9
# Out:
# Empty DataFrame
# Columns: [订单ID, 商品名称, 单价, 数量, 城市, 总价, 品类, 是否包邮, 下单时间]
# Index: []
