# %%
import pandas as pd

# %%
file1 = r'append_data1.csv'
file2 = r'append_data2.csv'
file3 = r'append_data3.csv'

df1 = pd.read_csv(file1, encoding='utf-8')
df2 = pd.read_csv(file2, encoding='utf-8')
df3 = pd.read_csv(file3, encoding='utf-8')

df1
# Out:
#    订单ID 商品名称    单价  数量  城市    总价
# 0  1001   手机  2999   2  北京  5998
# 1  1002   耳机   399   5  上海  1995
# 2  1003   卫衣   199  10  广州  1990

# %%
df2
# Out:
#    订单ID 商品名称   单价  数量  城市    总价
# 0  1004   水杯   59  20  深圳  1180
# 1  1005   键盘  899   3  北京  2697
# 2  1006   鼠标   99   8  上海   792

# %%
df3
# Out:
#    订单ID 商品名称   单价  数量   是否包邮
# 0  1007   裤子  299   6   True
# 1  1008   毛巾   19  15  False

# %%
df_append_basic = df1.append(df2, ignore_index=True)
df_append_basic
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_append_basic = df1.append(df2, ignore_index=True)
#       2 df_append_basic
#
# File E:\anaconda3\envs\Pandas\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df_append_basic = pd.concat([df1, df2], ignore_index=True)

df_append_basic
# Out:
#    订单ID 商品名称    单价  数量  城市    总价
# 0  1001   手机  2999   2  北京  5998
# 1  1002   耳机   399   5  上海  1995
# 2  1003   卫衣   199  10  广州  1990
# 3  1004   水杯    59  20  深圳  1180
# 4  1005   键盘   899   3  北京  2697
# 5  1006   鼠标    99   8  上海   792

# %%
df_custom = pd.DataFrame(
    {
        '订单ID': [1009],
        '商品名称': ['平板'],
        '单价': [1999],
        '数量': [4],
        '城市': ['北京'],
        '总价': [7996]
    }
)

df_custom
# Out:
#    订单ID 商品名称    单价  数量  城市    总价
# 0  1009   平板  1999   4  北京  7996

# %%
df_append_multi = pd.concat([df1, df2, df_custom], ignore_index=True)
df_append_multi
# Out:
#    订单ID 商品名称    单价  数量  城市    总价
# 0  1001   手机  2999   2  北京  5998
# 1  1002   耳机   399   5  上海  1995
# 2  1003   卫衣   199  10  广州  1990
# 3  1004   水杯    59  20  深圳  1180
# 4  1005   键盘   899   3  北京  2697
# 5  1006   鼠标    99   8  上海   792
# 6  1009   平板  1999   4  北京  7996

# %%
df_append_diff = pd.concat([df1, df3], ignore_index=True)
df_append_diff
# Out:
#    订单ID 商品名称    单价  数量   城市      总价   是否包邮
# 0  1001   手机  2999   2   北京  5998.0    NaN
# 1  1002   耳机   399   5   上海  1995.0    NaN
# 2  1003   卫衣   199  10   广州  1990.0    NaN
# 3  1007   裤子   299   6  NaN     NaN   True
# 4  1008   毛巾    19  15  NaN     NaN  False

# %%
df_dup = pd.DataFrame(
    {
        '订单ID': [1001, 1010],
        '商品名称': ['手机', '音箱'],
        '单价': [2999, 299],
        '数量': [2, 7],
        '城市': ['北京', '上海'],
        '总价': [5998, 2093]
    }
)

df_dup
# Out:
#    订单ID 商品名称    单价  数量  城市    总价
# 0  1001   手机  2999   2  北京  5998
# 1  1010   音箱   299   7  上海  2093

# %%
df1
# Out:
#    订单ID 商品名称    单价  数量  城市    总价
# 0  1001   手机  2999   2  北京  5998
# 1  1002   耳机   399   5  上海  1995
# 2  1003   卫衣   199  10  广州  1990

# %%
df2
# Out:
#    订单ID 商品名称   单价  数量  城市    总价
# 0  1004   水杯   59  20  深圳  1180
# 1  1005   键盘  899   3  北京  2697
# 2  1006   鼠标   99   8  上海   792

# %%
df_append_dup = pd.concat([df1, df2, df_dup], ignore_index=True)
df_append_dup
# Out:
#    订单ID 商品名称    单价  数量  城市    总价
# 0  1001   手机  2999   2  北京  5998
# 1  1002   耳机   399   5  上海  1995
# 2  1003   卫衣   199  10  广州  1990
# 3  1004   水杯    59  20  深圳  1180
# 4  1005   键盘   899   3  北京  2697
# 5  1006   鼠标    99   8  上海   792
# 6  1001   手机  2999   2  北京  5998
# 7  1010   音箱   299   7  上海  2093

# %%
df_append_dropdup = df_append_dup.drop_duplicates(subset='订单ID', keep='first')
df_append_dropdup
# Out:
#    订单ID 商品名称    单价  数量  城市    总价
# 0  1001   手机  2999   2  北京  5998
# 1  1002   耳机   399   5  上海  1995
# 2  1003   卫衣   199  10  广州  1990
# 3  1004   水杯    59  20  深圳  1180
# 4  1005   键盘   899   3  北京  2697
# 5  1006   鼠标    99   8  上海   792
# 7  1010   音箱   299   7  上海  2093

# %%
df_concat = pd.concat([df1, df2], ignore_index=True)

df_concat
# Out:
#    订单ID 商品名称    单价  数量  城市    总价
# 0  1001   手机  2999   2  北京  5998
# 1  1002   耳机   399   5  上海  1995
# 2  1003   卫衣   199  10  广州  1990
# 3  1004   水杯    59  20  深圳  1180
# 4  1005   键盘   899   3  北京  2697
# 5  1006   鼠标    99   8  上海   792
