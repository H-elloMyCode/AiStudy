# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
mysql_engine = create_engine('mysql+pymysql://root:123456abc@gz-cdb-ekasbukn.sql.tencentcdb.com:29432/pandas_test')

# %%
df_mysql = pd.read_sql('user_info', mysql_engine)
df_mysql
# Out:
#    id name  age city   salary
# 0   1   张三   25   北京   8000.0
# 1   2   李四   30   上海  10000.0
# 2   3   王五   28   广州      NaN
# 3   4   赵六   35   深圳  15000.0

# %%
df_mysql_query = pd.read_sql("select name, city, salary from user_info where age > 25", con=mysql_engine)

print(df_mysql_query)
# Out:
#   name city   salary
# 0   李四   上海  10000.0
# 1   王五   广州      NaN
# 2   赵六   深圳  15000.0

# %%
df_mysql_query
# Out:
#   name city   salary
# 0   李四   上海  10000.0
# 1   王五   广州      NaN
# 2   赵六   深圳  15000.0

# %%
sqlite_engine = create_engine('sqlite:///:memory:')

# %%
test_df = pd.DataFrame(
    {
        'name': ['张三', '李四', '王五'],
        'age': [25, 30, 28],
        'city': ['北京', '上海', '广州']
    }
)
test_df
# Out:
#   name  age city
# 0   张三   25   北京
# 1   李四   30   上海
# 2   王五   28   广州

# %%
test_df.to_sql('user_info', con=sqlite_engine, index=False)
# Out:
# 3

# %%
df_sqlite = pd.read_sql('user_info', con=sqlite_engine)
df_sqlite
# Out:
#   name  age city
# 0   张三   25   北京
# 1   李四   30   上海
# 2   王五   28   广州

# %%
mysql_engine.dispose()
sqlite_engine.dispose()

# %%
sqlite_engine2 = create_engine('sqlite:///user_info')
df_sqlite = pd.read_sql('user_info', con=sqlite_engine2)

df_sqlite
# Out:
#    id name  age city   salary
# 0   1   张三   25   北京   8000.0
# 1   2   李四   30   上海  10000.0
# 2   3   王五   28   广州      NaN
# 3   4   赵六   35   深圳  15000.0
