# %%
import pandas as pd
import numpy as np

# %%
file_path = r'missing_drop.csv'

df = pd.read_csv(file_path, encoding='utf-8')

df
# Out:
#    订单ID 商品名称      单价    数量   城市      总价        下单时间
# 0  1001   手机  2999.0   2.0   北京     NaN  2024-01-01
# 1  1002   耳机     NaN   5.0   上海  1995.0         NaN
# 2  1003   卫衣   199.0   NaN   广州  1990.0  2024-01-02
# 3  1004  NaN    59.0  20.0   深圳  1180.0  2024-01-02
# 4  1005   键盘   899.0   3.0  NaN  2697.0  2024-01-03
# 5  1006   鼠标    99.0   8.0   杭州   792.0  2024-01-03

# %%
print(len(df))
# Out:
# 6

# %%
print(len(df.columns))
# Out:
# 7

# %%
df_drop_row = df.dropna()
df_drop_row
# Out:
#    订单ID 商品名称    单价   数量  城市     总价        下单时间
# 5  1006   鼠标  99.0  8.0  杭州  792.0  2024-01-03

# %%
print(len(df_drop_row))
# Out:
# 1

# %%
df
# Out:
#    订单ID 商品名称      单价    数量   城市      总价        下单时间
# 0  1001   手机  2999.0   2.0   北京     NaN  2024-01-01
# 1  1002   耳机     NaN   5.0   上海  1995.0         NaN
# 2  1003   卫衣   199.0   NaN   广州  1990.0  2024-01-02
# 3  1004  NaN    59.0  20.0   深圳  1180.0  2024-01-02
# 4  1005   键盘   899.0   3.0  NaN  2697.0  2024-01-03
# 5  1006   鼠标    99.0   8.0   杭州   792.0  2024-01-03

# %%
df_drop_spec_col = df.dropna(subset=['单价', '城市'])
df_drop_spec_col
# Out:
#    订单ID 商品名称      单价    数量  城市      总价        下单时间
# 0  1001   手机  2999.0   2.0  北京     NaN  2024-01-01
# 2  1003   卫衣   199.0   NaN  广州  1990.0  2024-01-02
# 3  1004  NaN    59.0  20.0  深圳  1180.0  2024-01-02
# 5  1006   鼠标    99.0   8.0  杭州   792.0  2024-01-03

# %%
df
# Out:
#    订单ID 商品名称      单价    数量   城市      总价        下单时间
# 0  1001   手机  2999.0   2.0   北京     NaN  2024-01-01
# 1  1002   耳机     NaN   5.0   上海  1995.0         NaN
# 2  1003   卫衣   199.0   NaN   广州  1990.0  2024-01-02
# 3  1004  NaN    59.0  20.0   深圳  1180.0  2024-01-02
# 4  1005   键盘   899.0   3.0  NaN  2697.0  2024-01-03
# 5  1006   鼠标    99.0   8.0   杭州   792.0  2024-01-03

# %%
df_drop_col = df.dropna(thresh=len(df) * 0.9, axis=1)
df_drop_col
# Out:
#    订单ID
# 0  1001
# 1  1002
# 2  1003
# 3  1004
# 4  1005
# 5  1006

# %%
df
# Out:
#    订单ID 商品名称      单价    数量   城市      总价        下单时间
# 0  1001   手机  2999.0   2.0   北京     NaN  2024-01-01
# 1  1002   耳机     NaN   5.0   上海  1995.0         NaN
# 2  1003   卫衣   199.0   NaN   广州  1990.0  2024-01-02
# 3  1004  NaN    59.0  20.0   深圳  1180.0  2024-01-02
# 4  1005   键盘   899.0   3.0  NaN  2697.0  2024-01-03
# 5  1006   鼠标    99.0   8.0   杭州   792.0  2024-01-03

# %%
missing_ratio = (df.isnull().sum() / len(df)) * 100
missing_ratio
# Out:
# 订单ID     0.000000
# 商品名称    16.666667
# 单价      16.666667
# 数量      16.666667
# 城市      16.666667
# 总价      16.666667
# 下单时间    16.666667
# dtype: float64

# %%
cols_keep = missing_ratio[missing_ratio < 20].index
cols_keep
# Out:
# Index(['订单ID', '商品名称', '单价', '数量', '城市', '总价', '下单时间'], dtype='str')

# %%
df_keep_col = df[cols_keep].dropna()
df_keep_col
# Out:
#    订单ID 商品名称    单价   数量  城市     总价        下单时间
# 5  1006   鼠标  99.0  8.0  杭州  792.0  2024-01-03
