# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

# %%
x = np.linspace(-4, 4, 50)
y = np.linspace(-4, 4, 50)
X, Y = np.meshgrid(x, y)

# %%
X
# Out:
# array([[-4.        , -3.83673469, -3.67346939, ...,  3.67346939,
#          3.83673469,  4.        ],
#        [-4.        , -3.83673469, -3.67346939, ...,  3.67346939,
#          3.83673469,  4.        ],
#        [-4.        , -3.83673469, -3.67346939, ...,  3.67346939,
#          3.83673469,  4.        ],
#        ...,
#        [-4.        , -3.83673469, -3.67346939, ...,  3.67346939,
#          3.83673469,  4.        ],
#        [-4.        , -3.83673469, -3.67346939, ...,  3.67346939,
#          3.83673469,  4.        ],
#        [-4.        , -3.83673469, -3.67346939, ...,  3.67346939,
#          3.83673469,  4.        ]], shape=(50, 50))

# %%
Y
# Out:
# array([[-4.        , -4.        , -4.        , ..., -4.        ,
#         -4.        , -4.        ],
#        [-3.83673469, -3.83673469, -3.83673469, ..., -3.83673469,
#         -3.83673469, -3.83673469],
#        [-3.67346939, -3.67346939, -3.67346939, ..., -3.67346939,
#         -3.67346939, -3.67346939],
#        ...,
#        [ 3.67346939,  3.67346939,  3.67346939, ...,  3.67346939,
#          3.67346939,  3.67346939],
#        [ 3.83673469,  3.83673469,  3.83673469, ...,  3.83673469,
#          3.83673469,  3.83673469],
#        [ 4.        ,  4.        ,  4.        , ...,  4.        ,
#          4.        ,  4.        ]], shape=(50, 50))

# %%
Z = np.cos(np.sqrt(X ** 2 + Y ** 2))

# %%
Z
# Out:
# array([[0.8101836 , 0.73808097, 0.6582439 , ..., 0.6582439 , 0.73808097,
#         0.8101836 ],
#        [0.73808097, 0.65453943, 0.56413227, ..., 0.56413227, 0.65453943,
#         0.73808097],
#        [0.6582439 , 0.56413227, 0.46415577, ..., 0.46415577, 0.56413227,
#         0.6582439 ],
#        ...,
#        [0.6582439 , 0.56413227, 0.46415577, ..., 0.46415577, 0.56413227,
#         0.6582439 ],
#        [0.73808097, 0.65453943, 0.56413227, ..., 0.56413227, 0.65453943,
#         0.73808097],
#        [0.8101836 , 0.73808097, 0.6582439 , ..., 0.6582439 , 0.73808097,
#         0.8101836 ]], shape=(50, 50))

# %%
fig = plt.figure(figsize=(8, 5))

ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap="coolwarm", alpha=0.8)

ax.set_title("3D 画布套用 Seaborn 主题")
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid", palette="coolwarm")
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

fig = plt.figure(figsize=(8, 5))

ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap="coolwarm", alpha=0.8)

ax.set_title("3D 画布套用 Seaborn 主题")
plt.tight_layout()
plt.show()
