# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

# %%
df = pd.DataFrame(
    {
        "date": pd.date_range("2025-01-01", periods=20, freq="D"),
        "value": np.random.randint(10, 50, 20)
    }
)

df
# Out:
#          date  value
# 0  2025-01-01     12
# 1  2025-01-02     12
# 2  2025-01-03     34
# 3  2025-01-04     46
# 4  2025-01-05     13
# 5  2025-01-06     29
# 6  2025-01-07     34
# 7  2025-01-08     15
# 8  2025-01-09     29
# 9  2025-01-10     12
# 10 2025-01-11     30
# 11 2025-01-12     12
# 12 2025-01-13     21
# 13 2025-01-14     10
# 14 2025-01-15     27
# 15 2025-01-16     24
# 16 2025-01-17     11
# 17 2025-01-18     35
# 18 2025-01-19     17
# 19 2025-01-20     16

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    20 non-null     datetime64[us]
#  1   value   20 non-null     int32
# dtypes: datetime64[us](1), int32(1)
# memory usage: 372.0 bytes

# %%
df["date"] = pd.to_datetime(df["date"])
plt.figure(figsize=(10, 4))

sns.lineplot(data=df, x="date", y="value", color="#2E86AB", linewidth=2)

plt.title("时间轴格式适配")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame(
    {
        "date": pd.date_range("2025-01-01", periods=20, freq="D"),
        "value": np.random.randint(10, 50, 20)
    }
)

# df

# df["date"] = pd.to_datetime(df["date"])
plt.figure(figsize=(10, 4))

sns.lineplot(data=df, x="date", y="value", color="#2E86AB", linewidth=2)

plt.title("时间轴格式适配")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
# 这种场景才必须写 pd.to_datetime
df = pd.DataFrame({"date": ["2025-01-01", "2025-01-02"], "value": [10,20]})
# df["date"] = pd.to_datetime(df["date"])

plt.figure(figsize=(10, 4))

sns.lineplot(data=df, x="date", y="value", color="#2E86AB", linewidth=2)

plt.title("时间轴格式适配")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
# 这种场景才必须写 pd.to_datetime
df = pd.DataFrame({"date": ["2025-01-01", "2025-01-02"], "value": [10,20]})
df["date"] = pd.to_datetime(df["date"])

plt.figure(figsize=(10, 4))

sns.lineplot(data=df, x="date", y="value", color="#2E86AB", linewidth=2)

plt.title("时间轴格式适配")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()
