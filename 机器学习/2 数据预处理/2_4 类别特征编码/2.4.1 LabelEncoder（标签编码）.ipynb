# %%
from sklearn.preprocessing import LabelEncoder

# %%
labels = ['男', '女', '男', '女', '男', '女', '男']

# %%
len(labels)
# Out:
# 7

# %%
le = LabelEncoder()

encoded = le.fit_transform(labels)

print(f"原始标签: {labels}")
print(f"编码结果: {encoded}")
print(f"映射关系: {dict(zip(le.classes_, le.transform(le.classes_)))}")
# Out:
# 原始标签: ['男', '女', '男', '女', '男', '女', '男']
# 编码结果: [1 0 1 0 1 0 1]
# 映射关系: {np.str_('女'): np.int64(0), np.str_('男'): np.int64(1)}

# %%
encoded
# Out:
# array([1, 0, 1, 0, 1, 0, 1])

# %%
decoded = le.inverse_transform(encoded)

decoded
# Out:
# array(['男', '女', '男', '女', '男', '女', '男'], dtype='<U1')

# %%
print(f"解码还原: {list(decoded)}")
# Out:
# 解码还原: [np.str_('男'), np.str_('女'), np.str_('男'), np.str_('女'), np.str_('男'), np.str_('女'), np.str_('男')]

# %%
le.classes_
# Out:
# array(['女', '男'], dtype='<U1')

# %%
print(f"映射关系: {dict(zip(le.classes_, le.transform(le.classes_)))}")
# Out:
# 映射关系: {np.str_('女'): np.int64(0), np.str_('男'): np.int64(1)}
