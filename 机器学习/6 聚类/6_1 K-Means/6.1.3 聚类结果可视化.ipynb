# %%
from tkinter.tix import Y_REGION

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
X, _ = make_blobs(n_samples=300, centers=3, cluster_std=0.6, random_state=42)

# %%
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)

# %%
kmeans
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %%
y_pred = kmeans.fit_predict(X)
# Out:
# E:\anaconda3\envs\MachineLearning\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
y_pred
# Out:
# array([1, 1, 0, 2, 1, 2, 0, 2, 0, 0, 0, 2, 0, 0, 1, 0, 1, 2, 0, 0, 0, 0,
#        2, 1, 0, 1, 1, 2, 2, 0, 0, 0, 1, 0, 1, 0, 1, 2, 1, 2, 2, 0, 1, 2,
#        0, 0, 1, 2, 1, 2, 2, 1, 1, 0, 1, 2, 1, 0, 2, 0, 1, 2, 2, 1, 1, 2,
#        2, 1, 1, 0, 2, 1, 1, 0, 0, 1, 1, 2, 0, 2, 0, 0, 1, 0, 2, 1, 1, 0,
#        2, 0, 1, 0, 1, 0, 0, 1, 1, 0, 1, 1, 2, 0, 2, 0, 0, 0, 0, 0, 2, 1,
#        2, 0, 0, 0, 0, 2, 1, 2, 1, 2, 2, 2, 0, 1, 1, 1, 1, 0, 1, 1, 0, 0,
#        0, 0, 0, 2, 2, 1, 0, 1, 0, 0, 1, 0, 2, 2, 2, 0, 2, 0, 0, 1, 2, 1,
#        0, 2, 2, 1, 1, 0, 0, 1, 1, 1, 0, 1, 2, 0, 0, 0, 0, 0, 2, 0, 2, 2,
#        2, 0, 2, 2, 1, 0, 1, 2, 2, 1, 2, 0, 2, 2, 1, 1, 2, 1, 2, 2, 2, 2,
#        0, 1, 0, 0, 2, 2, 0, 2, 1, 1, 2, 0, 0, 1, 2, 2, 1, 1, 1, 1, 0, 1,
#        1, 2, 1, 1, 0, 2, 1, 1, 2, 0, 0, 1, 0, 1, 2, 2, 1, 2, 1, 1, 1, 2,
#        2, 0, 1, 2, 2, 2, 1, 2, 1, 2, 1, 2, 2, 1, 2, 0, 1, 0, 0, 0, 1, 0,
#        2, 2, 1, 2, 2, 0, 0, 2, 2, 2, 1, 1, 1, 0, 0, 0, 2, 2, 2, 2, 1, 2,
# ...

# %%
centers = kmeans.cluster_centers_

# %%
centers
# Out:
# array([[-2.58361866,  9.03185632],
#        [-6.88217395, -6.94243433],
#        [ 4.70421356,  1.99562444]])

# %%
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

plt.figure(figsize=(9, 6))

plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='viridis', s=40, alpha=0.7, edgecolor='k', linewidths=0.3)

plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=200, edgecolors='black', linewidths=1.5, label='质心')

plt.xlabel('特征 1')
plt.ylabel('特征 2')
plt.title('K-Means 聚类结果')
plt.legend()
plt.colorbar(label='簇标签')
plt.grid(True, alpha=0.2)

plt.show()

# %%
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

plt.figure(figsize=(9, 6))

plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='Set1', s=40, alpha=0.7, edgecolor='k', linewidths=0.3)

plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=200, edgecolors='black', linewidths=1.5, label='质心')

plt.xlabel('特征 1')
plt.ylabel('特征 2')
plt.title('K-Means 聚类结果')
plt.legend()
plt.colorbar(label='簇标签')
plt.grid(True, alpha=0.2)

plt.show()

# %%
plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

plt.figure(figsize=(9, 6))

plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='tab10', s=40, alpha=0.7, edgecolor='k', linewidths=0.3)

plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=200, edgecolors='black', linewidths=1.5, label='质心')

plt.xlabel('特征 1')
plt.ylabel('特征 2')
plt.title('K-Means 聚类结果')
plt.legend()
plt.colorbar(label='簇标签')
plt.grid(True, alpha=0.2)

plt.show()

# %%
X, _ = make_blobs(n_samples=500, centers=4, cluster_std=1.5, random_state=42)

kmeans = KMeans(n_clusters=4, random_state=42, n_init=10)

y_pred = kmeans.fit_predict(X)

centers = kmeans.cluster_centers_

plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

plt.figure(figsize=(9, 6))

plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='tab10', s=40, alpha=0.7, edgecolor='k', linewidths=0.3)

plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=200, edgecolors='black', linewidths=1.5, label='质心')

plt.xlabel('特征 1')
plt.ylabel('特征 2')
plt.title('K-Means 聚类结果')
plt.legend()
plt.colorbar(label='簇标签')
plt.grid(True, alpha=0.2)

plt.show()
# Out:
# E:\anaconda3\envs\MachineLearning\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
X, _ = make_blobs(n_samples=1000, centers=7, cluster_std=0.8, random_state=20)

kmeans = KMeans(n_clusters=7, random_state=20, n_init=10)

y_pred = kmeans.fit_predict(X)

centers = kmeans.cluster_centers_

plt.rcParams["font.sans-serif"] = ["SimHei"]
plt.rcParams["axes.unicode_minus"] = False

plt.figure(figsize=(9, 6))

plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='tab10', s=40, alpha=0.7, edgecolor='k', linewidths=0.3)

plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=200, edgecolors='black', linewidths=1.5, label='质心')

plt.xlabel('特征 1')
plt.ylabel('特征 2')
plt.title('K-Means 聚类结果')
plt.legend()
plt.colorbar(label='簇标签')
plt.grid(True, alpha=0.2)

plt.show()
# Out:
# E:\anaconda3\envs\MachineLearning\lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
