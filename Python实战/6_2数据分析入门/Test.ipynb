# %%
print("Hello World")
# Out:
# Hello World

# %%
for i in range(5):
    print(i)

# %% [markdown]
# #### 我正在学习python数据分析入门

# %%
import csv
import time

print(time.time())

# %%
# %%sql
# select * from aaa;
